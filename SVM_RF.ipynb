# %%
from itertools import product
import numpy as np
import pandas as pd
from ADRprofilePrediction import Pairs2Mat, evaluation
from Models import loadHyperpar
import seaborn as sns 
import matplotlib.pylab as plt
from matplotlib.ticker import MultipleLocator
import matplotlib.patheffects as path_effects
import json
import pingouin as pg

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 0.24.2

# %%
features_dict = {
    "target":Pairs2Mat(path="data/drug_target.tsv",colname1="0",colname2="1"),
    "enzyme":Pairs2Mat(path="data/drug_enzyme.tsv",colname1="0",colname2="1"),
    "Chem":pd.read_csv("data/drug_chemsfp.tsv",sep = "\t",header=0,index_col=0),
    "DGI":Pairs2Mat(path="data/interactions.tsv",colname1="drug_claim_name",colname2="gene_name"),
    "transporter":Pairs2Mat(path="data/drug_transporter.tsv",colname1="0",colname2="1"),
    "pathway":Pairs2Mat(path="data/drug_pathway.tsv",colname1="0",colname2="1"),
    "indication":Pairs2Mat(path="data/drug_indication.tsv",colname1="1_x",colname2="6")
}

# %%
filter = "all"
SEs = {}
if filter == "all":
    SIDER = Pairs2Mat(path="data/drug_se.tsv",colname1="1_x",colname2="5")
    column_sums = np.sum(SIDER, axis=0)
    SEs["SIDER"] = SIDER.loc[:, (column_sums >= 5)]

    OFFSIDERS = Pairs2Mat(path="data/OFFSIDES.csv",colname1="drug_concept_name",colname2="condition_concept_name",sep = ",")
    column_sums = np.sum(OFFSIDERS, axis=0)
    SEs["OFFSIDES"] = OFFSIDERS.loc[:, column_sums >= 5]
elif filter == "rare":
    SIDER = Pairs2Mat(path="data/drug_se.tsv",colname1="1_x",colname2="5")
    column_sums = np.sum(SIDER, axis=0)
    SEs["SIDER"] = SIDER.loc[:, (column_sums < 50)]

    OFFSIDERS = Pairs2Mat(path="data/OFFSIDES.csv",colname1="drug_concept_name",colname2="condition_concept_name",sep = ",")
    column_sums = np.sum(OFFSIDERS, axis=0)
    SEs["OFFSIDES"] = OFFSIDERS.loc[:, column_sums < 50]

# %%
features_names = ["pathway"]
# SEs_names = ["SIDER", "OFFSIDES"]
# methods = ["SKR", "KR", "KRR", "Naive", "LNSM_RLN", "LNSM_jaccard", "VKR"]
methods = ["SVM", "RF", "BRF"]
# methods = ["SKR", "KR", "KRR", "Naive", "LNSM_RLN", "LNSM_jaccard", "VKR", "SVM", "OCCA", "SCCA", "RF", "BRF"]
tuning_metrices=["AUROC", "AUPR", "AUROCperdrug", "AUPRperdrug"]
metrice_names = ["AUPR+AUROC", "AUPR+AUROCperdrug", "AUROC", "AUPR", "AUROCperdrug", "AUPRperdrug"]

# %%
A = 10**np.arange(-2, 3, 1, dtype=float)
B = np.arange(0.1, 1, 0.1, dtype=float)
C = np.arange(5, 20, 5, dtype=int)
A10 = 10**np.arange(1, 2, 1, dtype=float)
A100 = 10**np.arange(2, 3, 1, dtype=float)
all_hyperparlist = {
    "SKR":[A,B,A10,A100], 
    # "KR":[A,A], 
    "KRR":[A,A],
    "VKR":[A,A,C], 
    "Naive":[], 
    "LNSM_RLN":[B,A], 
    "LNSM_jaccard":[B], 
    "SVM":[A,A], 
    # "OCCA":[], 
    # "SCCA":[A], 
    "RF":[C], 
    "BRF":[C]
}

# %%
hyperpars = {}
hyperpars["nested_cv"] = {}
hyperpars["cv"] = {}
hyperparsOut = {}
hyperparsOut["nested_cv"] = {}
hyperparsOut["cv"] = {}
results = {}
results["nested_cv"] = {}
results["cv"] = {}

# %%
SEs_name = "SIDER"
metrice = "AUPR"

# %%
hyperpars["nested_cv"]["SVM"] = {}
hyperpars["cv"]["SVM"] = {}
hyperpars["nested_cv"]["SVM"]["pathway"] = [
    (100, 100),
    (0.1, 10),
    (0.1, 10),
    (10, 10),
    (10, 10),
    ]

hyperpars["cv"]["SVM"]["pathway"] = (10, 10)

# %%
hyperpars["nested_cv"]["RF"] = {}
hyperpars["cv"]["RF"] = {}
hyperpars["nested_cv"]["RF"]["pathway"] = [
    (15,),
    (15,),
    (15,),
    (15,),
    (15,),
    ]

hyperpars["cv"]["RF"]["pathway"] = (15,)

# %%
hyperpars["nested_cv"]["BRF"] = {}
hyperpars["cv"]["BRF"] = {}
hyperpars["nested_cv"]["BRF"]["pathway"] = [
    (15,),
    (15,),
    (15,),
    (15,),
    (15,),
    ]

hyperpars["cv"]["BRF"]["pathway"] = (15,)

# %%
import time

# %%
for method in methods:
    # # method = "SKR"
    validation = "nested_cv"
    hyperparsOut[validation][method] = {}
    results[validation][method] = {}
    for str in features_names:
        print(f"using feature {str}")
        hyperparList = loadHyperpar(*all_hyperparlist[method],method_option=method)
        t1 = time.time()
        results[validation][method][str], hyperparsOut[validation][method][str] = evaluation(Y=SEs[SEs_name], X=features_dict[str], method_option=method,tuning_metrice=metrice,hyperparList=hyperparList,hyperparfixed=hyperpars[validation][method][str],Validation=validation,n_jobs=1)
        t2 = time.time()
        print("run time: ", t2 - t1)

    # method = "SKR"
    validation = "cv"
    hyperparsOut[validation][method] = {}
    results[validation][method] = {}
    for str in features_names:
        print(f"using feature {str}")
        hyperparList = loadHyperpar(*all_hyperparlist[method],method_option=method)
        t1 = time.time()
        results[validation][method][str], hyperparsOut[validation][method][str] = evaluation(Y=SEs[SEs_name], X=features_dict[str], method_option=method,tuning_metrice=metrice,hyperparList=hyperparList,hyperparfixed=hyperpars[validation][method][str],Validation=validation,n_jobs=1)
        t2 = time.time()
        print("run time: ", t2 - t1)
# Out:
# using feature pathway
# The SVM requires hyperparameter c, gamma
# ---------- nested cv start ----------
# Fold: 0
# number of hyperpars combination:  25
# first few training idx:  [ 96 127 200 219 286 391 395 415 454 484]
# first few testing idx:  [ 48  78  94 164 192 373 396 402 481 487]
# --- tuning end ---
# target size: 106
# ------ best hyper pars:  (100, 100) ------
# SVM starts:
# SVM ends:
# -----------
# AUPRperdrug: 0.41924003232058354
# AUROCperdrug: 0.8720250072102603
# AUPR+AUROCperdrug: 1.2912650395308438
# AUPR: 0.36227197049316584
# AUROC: 0.8425448573029706
# AUPR+AUROC: 1.2048168277961364
# -----------
# Fold: 1
# number of hyperpars combination:  25
# first few training idx:  [ 48  78  94 164 192 373 396 402 481 487]
# first few testing idx:  [ 96 127 200 219 286 391 395 415 454 484]
# --- tuning end ---
# target size: 106
# ------ best hyper pars:  (0.1, 10) ------
# SVM starts:
# SVM ends:
# -----------
# AUPRperdrug: 0.4403688965928966
# AUROCperdrug: 0.8808364554703981
# AUPR+AUROCperdrug: 1.3212053520632947
# AUPR: 0.3931012269464438
# AUROC: 0.8579066095899085
# AUPR+AUROC: 1.2510078365363522
# -----------
# Fold: 2
# number of hyperpars combination:  25
# first few training idx:  [ 48  78  94 164 192 373 396 402 481 487]
# first few testing idx:  [ 21  53  60 124 153 208 213 300 427 431]
# --- tuning end ---
# target size: 106
# ------ best hyper pars:  (0.1, 10) ------
# SVM starts:
# SVM ends:
# -----------
# AUPRperdrug: 0.43396542795063836
# AUROCperdrug: 0.8705677875000196
# AUPR+AUROCperdrug: 1.304533215450658
# AUPR: 0.3781703185124826
# AUROC: 0.8430441298296025
# AUPR+AUROC: 1.221214448342085
# -----------
# Fold: 3
# number of hyperpars combination:  25
# first few training idx:  [ 48  78  94 164 192 373 396 402 481 487]
# first few testing idx:  [ 31 107 114 218 229 240 262 263 420 434]
# --- tuning end ---
# target size: 106
# ------ best hyper pars:  (10, 10) ------
# SVM starts:
# SVM ends:
# -----------
# AUPRperdrug: 0.42372140599177716
# AUROCperdrug: 0.8748363229149396
# AUPR+AUROCperdrug: 1.2985577289067167
# AUPR: 0.37451731579253406
# AUROC: 0.8535446951862532
# AUPR+AUROC: 1.2280620109787872
# -----------
# Fold: 4
# number of hyperpars combination:  25
# first few training idx:  [ 48  78  94 164 192 373 396 402 481 487]
# first few testing idx:  [ 26 115 163 214 278 325 387 408 440 501]
# --- tuning end ---
# target size: 106
# ------ best hyper pars:  (10, 10) ------
# SVM starts:
# SVM ends:
# -----------
# AUPRperdrug: 0.4291303573396122
# AUROCperdrug: 0.873034656077884
# AUPR+AUROCperdrug: 1.3021650134174962
# AUPR: 0.38494774841478874
# AUROC: 0.8577813867821948
# AUPR+AUROC: 1.2427291351969836
# -----------
# Mean AUPRperdrug: 0.4292852240391015, std: 0.007438252987811583
# Mean AUROCperdrug: 0.8742600458347004, std: 0.0035696220609071822
# Mean AUPR+AUROCperdrug: 1.3035452698738017, std: 0.009903931234233252
# Mean AUPR: 0.378601716031883, std: 0.010334766202101981
# Mean AUROC: 0.850964335738186, std: 0.006854821439039528
# Mean AUPR+AUROC: 1.2295660517700688, std: 0.016233005914491366
# -----------
# run time:  85.21148204803467
# using feature pathway
# The SVM requires hyperparameter c, gamma
# ---------- cv start ----------
# --- tuning end ---
# target size: 180
# ------ best hyper pars:  (10, 10) ------
# SVM starts:
# SVM ends:
# -----------
# AUPRperdrug: 0.4515203938299791
# AUROCperdrug: 0.8780329215278591
# AUPR+AUROCperdrug: 1.3295533153578383
# AUPR: 0.3931186488444532
# AUROC: 0.8486138128633915
# AUPR+AUROC: 1.2417324617078447
# -----------
# run time:  27.174490928649902
# using feature pathway
# The RF requires hyperparameter k
# ---------- nested cv start ----------
# Fold: 0
# number of hyperpars combination:  3
# first few training idx:  [ 96 127 200 219 286 391 395 415 454 484]
# first few testing idx:  [ 48  78  94 164 192 373 396 402 481 487]
# --- tuning end ---
# target size: 106
# ------ best hyper pars:  (15,) ------
# RF starts:
# RF ends:
# -----------
# AUPRperdrug: 0.4538029801630281
# AUROCperdrug: 0.83670190494197
# AUPR+AUROCperdrug: 1.290504885104998
# AUPR: 0.38547000391440334
# AUROC: 0.8096315480524837
# AUPR+AUROC: 1.195101551966887
# -----------
# Fold: 1
# number of hyperpars combination:  3
# first few training idx:  [ 48  78  94 164 192 373 396 402 481 487]
# first few testing idx:  [ 96 127 200 219 286 391 395 415 454 484]
# --- tuning end ---
# target size: 106
# ------ best hyper pars:  (15,) ------
# RF starts:
# RF ends:
# -----------
# AUPRperdrug: 0.4833066222252045
# AUROCperdrug: 0.8495110065660645
# AUPR+AUROCperdrug: 1.332817628791269
# AUPR: 0.4132145351142228
# AUROC: 0.8204455670525831
# AUPR+AUROC: 1.2336601021668059
# -----------
# Fold: 2
# number of hyperpars combination:  3
# first few training idx:  [ 48  78  94 164 192 373 396 402 481 487]
# first few testing idx:  [ 21  53  60 124 153 208 213 300 427 431]
# --- tuning end ---
# target size: 106
# ------ best hyper pars:  (15,) ------
# RF starts:
# RF ends:
# -----------
# AUPRperdrug: 0.450998924123452
# AUROCperdrug: 0.839943064036148
# AUPR+AUROCperdrug: 1.2909419881596
# AUPR: 0.4061416041213282
# AUROC: 0.8101695168088594
# AUPR+AUROC: 1.2163111209301876
# -----------
# Fold: 3
# number of hyperpars combination:  3
# first few training idx:  [ 48  78  94 164 192 373 396 402 481 487]
# first few testing idx:  [ 31 107 114 218 229 240 262 263 420 434]
# --- tuning end ---
# target size: 106
# ------ best hyper pars:  (15,) ------
# RF starts:
# RF ends:
# -----------
# AUPRperdrug: 0.4817796391112474
# AUROCperdrug: 0.8396554463107821
# AUPR+AUROCperdrug: 1.3214350854220296
# AUPR: 0.3847174453349166
# AUROC: 0.8116334407308423
# AUPR+AUROC: 1.1963508860657588
# -----------
# Fold: 4
# number of hyperpars combination:  3
# first few training idx:  [ 48  78  94 164 192 373 396 402 481 487]
# first few testing idx:  [ 26 115 163 214 278 325 387 408 440 501]
# --- tuning end ---
# target size: 106
# ------ best hyper pars:  (15,) ------
# RF starts:
# RF ends:
# -----------
# AUPRperdrug: 0.4641287999499082
# AUROCperdrug: 0.8446028321628256
# AUPR+AUROCperdrug: 1.3087316321127338
# AUPR: 0.41384110087340076
# AUROC: 0.820839263586944
# AUPR+AUROC: 1.2346803644603448
# -----------
# Mean AUPRperdrug: 0.4668033931145681, std: 0.013583739844603718
# Mean AUROCperdrug: 0.842082850803558, std: 0.004493403218719329
# Mean AUPR+AUROCperdrug: 1.308886243918126, std: 0.01667380686220939
# Mean AUPR: 0.40067693787165437, std: 0.013010037292676111
# Mean AUROC: 0.8145438672463424, std: 0.005023912415690145
# Mean AUPR+AUROC: 1.2152208051179967, std: 0.017208887857263468
# -----------
# run time:  10.053731918334961
# using feature pathway
# The RF requires hyperparameter k
# ---------- cv start ----------
# --- tuning end ---
# target size: 180
# ------ best hyper pars:  (15,) ------
# RF starts:
# RF ends:
# -----------
# AUPRperdrug: 0.47212634204237136
# AUROCperdrug: 0.8466606098670126
# AUPR+AUROCperdrug: 1.318786951909384
# AUPR: 0.39716534932872694
# AUROC: 0.8243061294982998
# AUPR+AUROC: 1.2214714788270267
# -----------
# run time:  3.4844322204589844
# using feature pathway
# The BRF requires hyperparameter k
# ---------- nested cv start ----------
# Fold: 0
# number of hyperpars combination:  3
# first few training idx:  [ 96 127 200 219 286 391 395 415 454 484]
# first few testing idx:  [ 48  78  94 164 192 373 396 402 481 487]
# --- tuning end ---
# target size: 106
# ------ best hyper pars:  (15,) ------
# BRF starts:
# BRF ends:
# -----------
# AUPRperdrug: 0.45380069234283477
# AUROCperdrug: 0.836701587563041
# AUPR+AUROCperdrug: 1.2905022799058758
# AUPR: 0.38550093287762216
# AUROC: 0.809635022719387
# AUPR+AUROC: 1.1951359555970091
# -----------
# Fold: 1
# number of hyperpars combination:  3
# first few training idx:  [ 48  78  94 164 192 373 396 402 481 487]
# first few testing idx:  [ 96 127 200 219 286 391 395 415 454 484]
# --- tuning end ---
# target size: 106
# ------ best hyper pars:  (15,) ------
# BRF starts:
# BRF ends:
# -----------
# AUPRperdrug: 0.4833070372040809
# AUROCperdrug: 0.8495111025792647
# AUPR+AUROCperdrug: 1.3328181397833456
# AUPR: 0.41321138210450625
# AUROC: 0.8204454330542194
# AUPR+AUROC: 1.2336568151587257
# -----------
# Fold: 2
# number of hyperpars combination:  3
# first few training idx:  [ 48  78  94 164 192 373 396 402 481 487]
# first few testing idx:  [ 21  53  60 124 153 208 213 300 427 431]
# --- tuning end ---
# target size: 106
# ------ best hyper pars:  (15,) ------
# BRF starts:
# BRF ends:
# -----------
# AUPRperdrug: 0.45100511554751965
# AUROCperdrug: 0.839943640138628
# AUPR+AUROCperdrug: 1.2909487556861476
# AUPR: 0.4061292114419609
# AUROC: 0.8101682311491715
# AUPR+AUROC: 1.2162974425911324
# -----------
# Fold: 3
# number of hyperpars combination:  3
# first few training idx:  [ 48  78  94 164 192 373 396 402 481 487]
# first few testing idx:  [ 31 107 114 218 229 240 262 263 420 434]
# --- tuning end ---
# target size: 106
# ------ best hyper pars:  (15,) ------
# BRF starts:
# BRF ends:
# -----------
# AUPRperdrug: 0.4817862573358663
# AUROCperdrug: 0.8396537632041784
# AUPR+AUROCperdrug: 1.3214400205400447
# AUPR: 0.3847157274877779
# AUROC: 0.8116333829256855
# AUPR+AUROC: 1.1963491104134634
# -----------
# Fold: 4
# number of hyperpars combination:  3
# first few training idx:  [ 48  78  94 164 192 373 396 402 481 487]
# first few testing idx:  [ 26 115 163 214 278 325 387 408 440 501]
# --- tuning end ---
# target size: 106
# ------ best hyper pars:  (15,) ------
# BRF starts:
# BRF ends:
# -----------
# AUPRperdrug: 0.46412695789007286
# AUROCperdrug: 0.8446028349697884
# AUPR+AUROCperdrug: 1.3087297928598614
# AUPR: 0.4138410589254204
# AUROC: 0.82083913298137
# AUPR+AUROC: 1.2346801919067905
# -----------
# Mean AUPRperdrug: 0.4668052120640748, std: 0.013584370275577308
# Mean AUROCperdrug: 0.84208258569098, std: 0.0044936383296404
# Mean AUPR+AUROCperdrug: 1.3088877977550548, std: 0.01667381797258448
# Mean AUPR: 0.40067966256745746, std: 0.013001576749052893
# Mean AUROC: 0.8145442405659666, std: 0.00502339952199607
# Mean AUPR+AUROC: 1.215223903133424, std: 0.01720032175268608
# -----------
# run time:  426.8150963783264
# using feature pathway
# The BRF requires hyperparameter k
# ---------- cv start ----------
# --- tuning end ---
# target size: 180
# ------ best hyper pars:  (15,) ------
# BRF starts:
# BRF ends:
# -----------
# AUPRperdrug: 0.4721516685314481
# AUROCperdrug: 0.8466616909223009
# AUPR+AUROCperdrug: 1.318813359453749
# AUPR: 0.3971595336030938
# AUROC: 0.8243064534805549
# AUPR+AUROC: 1.2214659870836486
# -----------
# run time:  102.9158353805542

# %%
SEs_name = "OFFSIDES"
metrice = "AUPR"

# %%
hyperpars["nested_cv"]["pathway"] = {}
hyperpars["cv"]["SVM"] = {}
hyperpars["nested_cv"]["SVM"]["pathway"] = [
    (10, 10),
    (100, 100),
    (100, 100),
    (100, 100),
    (10, 10),
    ]

hyperpars["cv"]["SVM"]["pathway"] = (0.1, 10)

# %%
hyperpars["nested_cv"]["RF"] = {}
hyperpars["cv"]["RF"] = {}
hyperpars["nested_cv"]["RF"]["pathway"] = [
    (15,),
    (15,),
    (15,),
    (15,),
    (15,),
    ]

hyperpars["cv"]["RF"]["pathway"] = (15,)

# %%
hyperpars["nested_cv"]["BRF"] = {}
hyperpars["cv"]["BRF"] = {}
hyperpars["nested_cv"]["BRF"]["pathway"] = [
    (15,),
    (15,),
    (15,),
    (15,),
    (15,),
    ]

hyperpars["cv"]["BRF"]["pathway"] = (15,)

# %%
for method in methods:
    # # method = "SKR"
    validation = "nested_cv"
    hyperparsOut[validation][method] = {}
    results[validation][method] = {}
    for str in features_names:
        print(f"using feature {str}")
        t1 = time.time()
        hyperparList = loadHyperpar(*all_hyperparlist[method],method_option=method)
        results[validation][method][str], hyperparsOut[validation][method][str] = evaluation(Y=SEs[SEs_name], X=features_dict[str], method_option=method,tuning_metrice=metrice,hyperparList=hyperparList,hyperparfixed=hyperpars[validation][method][str],Validation=validation,n_jobs=1)
        t2 = time.time()
        print("run time: ", t2 - t1)

    # method = "SKR"
    validation = "cv"
    hyperparsOut[validation][method] = {}
    results[validation][method] = {}
    for str in features_names:
        print(f"using feature {str}")
        t1 = time.time()
        hyperparList = loadHyperpar(*all_hyperparlist[method],method_option=method)
        results[validation][method][str], hyperparsOut[validation][method][str] = evaluation(Y=SEs[SEs_name], X=features_dict[str], method_option=method,tuning_metrice=metrice,hyperparList=hyperparList,hyperparfixed=hyperpars[validation][method][str],Validation=validation,n_jobs=1)
        t2 = time.time()
        print("run time: ", t2 - t1)
# Out:
# using feature pathway
# The SVM requires hyperparameter c, gamma
# ---------- nested cv start ----------
# Fold: 0
# number of hyperpars combination:  25
# first few training idx:  [  7 158 245 251 274 323 440 462 642 743]
# first few testing idx:  [ 10  36  92 145 470 503 590 640 711 730]
# --- tuning end ---
# target size: 150
# ------ best hyper pars:  (10, 10) ------
# SVM starts:
# SVM ends:
# -----------
# AUPRperdrug: 0.6303730471183844
# AUROCperdrug: 0.9439565758547991
# AUPR+AUROCperdrug: 1.5743296229731834
# AUPR: 0.48201782850598107
# AUROC: 0.8419971284550303
# AUPR+AUROC: 1.3240149569610113
# -----------
# Fold: 1
# number of hyperpars combination:  25
# first few training idx:  [ 10  36  92 145 470 503 590 640 711 730]
# first few testing idx:  [  7 158 245 251 274 323 440 462 642 743]
# --- tuning end ---
# target size: 150
# ------ best hyper pars:  (100, 100) ------
# SVM starts:
# SVM ends:
# -----------
# AUPRperdrug: 0.6414820509514807
# AUROCperdrug: 0.9429120497578329
# AUPR+AUROCperdrug: 1.5843941007093136
# AUPR: 0.5008889906952898
# AUROC: 0.8332021272074119
# AUPR+AUROC: 1.3340911179027017
# -----------
# Fold: 2
# number of hyperpars combination:  25
# first few training idx:  [ 10  36  92 145 470 503 590 640 711 730]
# first few testing idx:  [ 26  84 219 261 337 365 430 466 489 639]
# --- tuning end ---
# target size: 150
# ------ best hyper pars:  (100, 100) ------
# SVM starts:
# SVM ends:
# -----------
# AUPRperdrug: 0.6497266143230579
# AUROCperdrug: 0.9439436662987994
# AUPR+AUROCperdrug: 1.5936702806218572
# AUPR: 0.5078497280169019
# AUROC: 0.8480535717205467
# AUPR+AUROC: 1.3559032997374487
# -----------
# Fold: 3
# number of hyperpars combination:  25
# first few training idx:  [ 10  36  92 145 470 503 590 640 711 730]
# first few testing idx:  [ 32 103 111 172 206 280 312 434 511 666]
# --- tuning end ---
# target size: 150
# ------ best hyper pars:  (100, 100) ------
# SVM starts:
# SVM ends:
# -----------
# AUPRperdrug: 0.6523288605933246
# AUROCperdrug: 0.9431873611741727
# AUPR+AUROCperdrug: 1.5955162217674972
# AUPR: 0.5082659828109808
# AUROC: 0.8382995733878784
# AUPR+AUROC: 1.3465655561988592
# -----------
# Fold: 4
# number of hyperpars combination:  25
# first few training idx:  [ 10  36  92 145 470 503 590 640 711 730]
# first few testing idx:  [199 240 294 346 463 528 574 624 724 734]
# --- tuning end ---
# target size: 150
# ------ best hyper pars:  (10, 10) ------
# SVM starts:
# SVM ends:
# -----------
# AUPRperdrug: 0.6484652300580895
# AUROCperdrug: 0.9428179233593093
# AUPR+AUROCperdrug: 1.5912831534173988
# AUPR: 0.5173614993823021
# AUROC: 0.8465451511777298
# AUPR+AUROC: 1.363906650560032
# -----------
# Mean AUPRperdrug: 0.6444751606088674, std: 0.007912108872953773
# Mean AUROCperdrug: 0.9433635152889828, std: 0.0004941291289983775
# Mean AUPR+AUROCperdrug: 1.58783867589785, std: 0.00773532622157853
# Mean AUPR: 0.5032768058822912, std: 0.011847597855413318
# Mean AUROC: 0.8416195103897195, std: 0.005434629685978496
# Mean AUPR+AUROC: 1.3448963162720107, std: 0.014409138316771772
# -----------
# run time:  1181.198459148407
# using feature pathway
# The SVM requires hyperparameter c, gamma
# ---------- cv start ----------
# --- tuning end ---
# target size: 261
# ------ best hyper pars:  (0.1, 10) ------
# SVM starts:
# SVM ends:
# -----------
# AUPRperdrug: 0.6360298494290889
# AUROCperdrug: 0.9427122815747171
# AUPR+AUROCperdrug: 1.5787421310038061
# AUPR: 0.4839018963043342
# AUROC: 0.8267511571675927
# AUPR+AUROC: 1.310653053471927
# -----------
# run time:  382.90489196777344
# using feature pathway
# The RF requires hyperparameter k
# ---------- nested cv start ----------
# Fold: 0
# number of hyperpars combination:  3
# first few training idx:  [  7 158 245 251 274 323 440 462 642 743]
# first few testing idx:  [ 10  36  92 145 470 503 590 640 711 730]
# --- tuning end ---
# target size: 150
# ------ best hyper pars:  (15,) ------
# RF starts:
# RF ends:
# -----------
# AUPRperdrug: 0.5871322039185238
# AUROCperdrug: 0.9092434411442908
# AUPR+AUROCperdrug: 1.4963756450628147
# AUPR: 0.43828031744269463
# AUROC: 0.8199508420005733
# AUPR+AUROC: 1.258231159443268
# -----------
# Fold: 1
# number of hyperpars combination:  3
# first few training idx:  [ 10  36  92 145 470 503 590 640 711 730]
# first few testing idx:  [  7 158 245 251 274 323 440 462 642 743]
# --- tuning end ---
# target size: 150
# ------ best hyper pars:  (15,) ------
# RF starts:
# RF ends:
# -----------
# AUPRperdrug: 0.6082666953006963
# AUROCperdrug: 0.9056162138876612
# AUPR+AUROCperdrug: 1.5138829091883577
# AUPR: 0.4867656993553793
# AUROC: 0.7997628258755538
# AUPR+AUROC: 1.286528525230933
# -----------
# Fold: 2
# number of hyperpars combination:  3
# first few training idx:  [ 10  36  92 145 470 503 590 640 711 730]
# first few testing idx:  [ 26  84 219 261 337 365 430 466 489 639]
# --- tuning end ---
# target size: 150
# ------ best hyper pars:  (15,) ------
# RF starts:
# RF ends:
# -----------
# AUPRperdrug: 0.6006795497812069
# AUROCperdrug: 0.9039937872653491
# AUPR+AUROCperdrug: 1.504673337046556
# AUPR: 0.4951332011398848
# AUROC: 0.8180159881886704
# AUPR+AUROC: 1.3131491893285552
# -----------
# Fold: 3
# number of hyperpars combination:  3
# first few training idx:  [ 10  36  92 145 470 503 590 640 711 730]
# first few testing idx:  [ 32 103 111 172 206 280 312 434 511 666]
# --- tuning end ---
# target size: 150
# ------ best hyper pars:  (15,) ------
# RF starts:
# RF ends:
# -----------
# AUPRperdrug: 0.6042853219907643
# AUROCperdrug: 0.897697037157776
# AUPR+AUROCperdrug: 1.5019823591485404
# AUPR: 0.48272876036353124
# AUROC: 0.8080534709527836
# AUPR+AUROC: 1.2907822313163149
# -----------
# Fold: 4
# number of hyperpars combination:  3
# first few training idx:  [ 10  36  92 145 470 503 590 640 711 730]
# first few testing idx:  [199 240 294 346 463 528 574 624 724 734]
# --- tuning end ---
# target size: 150
# ------ best hyper pars:  (15,) ------
# RF starts:
# RF ends:
# -----------
# AUPRperdrug: 0.6003887432037535
# AUROCperdrug: 0.8981657638643538
# AUPR+AUROCperdrug: 1.4985545070681072
# AUPR: 0.4563485519501622
# AUROC: 0.7932776731848545
# AUPR+AUROC: 1.2496262251350168
# -----------
# Mean AUPRperdrug: 0.600150502838989, std: 0.007110303304563325
# Mean AUROCperdrug: 0.9029432486638862, std: 0.004433686861009172
# Mean AUPR+AUROCperdrug: 1.503093751502875, std: 0.006097112450920325
# Mean AUPR: 0.47185130605033043, std: 0.021213917317359225
# Mean AUROC: 0.8078121600404872, std: 0.010271971847873143
# Mean AUPR+AUROC: 1.2796634660908175, std: 0.023037487928864148
# -----------
# run time:  84.21126389503479
# using feature pathway
# The RF requires hyperparameter k
# ---------- cv start ----------
# --- tuning end ---
# target size: 261
# ------ best hyper pars:  (15,) ------
# RF starts:
# RF ends:
# -----------
# AUPRperdrug: 0.5956199267210065
# AUROCperdrug: 0.9045529653223892
# AUPR+AUROCperdrug: 1.5001728920433957
# AUPR: 0.49802869249815485
# AUROC: 0.8006634155601737
# AUPR+AUROC: 1.2986921080583285
# -----------
# run time:  31.73562979698181
# using feature pathway
# The BRF requires hyperparameter k
# ---------- nested cv start ----------
# Fold: 0
# number of hyperpars combination:  3
# first few training idx:  [  7 158 245 251 274 323 440 462 642 743]
# first few testing idx:  [ 10  36  92 145 470 503 590 640 711 730]
# --- tuning end ---
# target size: 150
# ------ best hyper pars:  (15,) ------
# BRF starts:
# BRF ends:
# -----------
# AUPRperdrug: 0.5871321026617524
# AUROCperdrug: 0.9092435013413859
# AUPR+AUROCperdrug: 1.4963756040031382
# AUPR: 0.4382806474696387
# AUROC: 0.8199510110507479
# AUPR+AUROC: 1.2582316585203865
# -----------
# Fold: 1
# number of hyperpars combination:  3
# first few training idx:  [ 10  36  92 145 470 503 590 640 711 730]
# first few testing idx:  [  7 158 245 251 274 323 440 462 642 743]
# --- tuning end ---
# target size: 150
# ------ best hyper pars:  (15,) ------
# BRF starts:
# BRF ends:
# -----------
# AUPRperdrug: 0.6082725296787754
# AUROCperdrug: 0.9056162906134811
# AUPR+AUROCperdrug: 1.5138888202922565
# AUPR: 0.4867622460936679
# AUROC: 0.7997629025928606
# AUPR+AUROC: 1.2865251486865286
# -----------
# Fold: 2
# number of hyperpars combination:  3
# first few training idx:  [ 10  36  92 145 470 503 590 640 711 730]
# first few testing idx:  [ 26  84 219 261 337 365 430 466 489 639]
# --- tuning end ---
# target size: 150
# ------ best hyper pars:  (15,) ------
# BRF starts:
# BRF ends:
# -----------
# AUPRperdrug: 0.6006791382659745
# AUROCperdrug: 0.9039941254678819
# AUPR+AUROCperdrug: 1.5046732637338565
# AUPR: 0.49517184974744616
# AUROC: 0.8180169461304708
# AUPR+AUROC: 1.313188795877917
# -----------
# Fold: 3
# number of hyperpars combination:  3
# first few training idx:  [ 10  36  92 145 470 503 590 640 711 730]
# first few testing idx:  [ 32 103 111 172 206 280 312 434 511 666]
# --- tuning end ---
# target size: 150
# ------ best hyper pars:  (15,) ------
# BRF starts:
# BRF ends:
# -----------
# AUPRperdrug: 0.604330679452493
# AUROCperdrug: 0.8976970924005673
# AUPR+AUROCperdrug: 1.5020277718530601
# AUPR: 0.4827311548844745
# AUROC: 0.8080535873864413
# AUPR+AUROC: 1.2907847422709158
# -----------
# Fold: 4
# number of hyperpars combination:  3
# first few training idx:  [ 10  36  92 145 470 503 590 640 711 730]
# first few testing idx:  [199 240 294 346 463 528 574 624 724 734]
# --- tuning end ---
# target size: 150
# ------ best hyper pars:  (15,) ------
# BRF starts:
# BRF ends:
# -----------
# AUPRperdrug: 0.6004016899266539
# AUROCperdrug: 0.898171797756043
# AUPR+AUROCperdrug: 1.4985734876826968
# AUPR: 0.4563435080416467
# AUROC: 0.7932770138304738
# AUPR+AUROC: 1.2496205218721204
# -----------
# Mean AUPRperdrug: 0.6001632279971298, std: 0.007117045460026165
# Mean AUROCperdrug: 0.9029445615158718, std: 0.004432416266756278
# Mean AUPR+AUROCperdrug: 1.5031077895130014, std: 0.006094751630258735
# Mean AUPR: 0.47185788124737477, std: 0.021222797659179345
# Mean AUROC: 0.8078122921981988, std: 0.010272377240661625
# Mean AUPR+AUROC: 1.2796701734455738, std: 0.02305043972410406
# -----------
# run time:  3293.028088569641
# using feature pathway
# The BRF requires hyperparameter k
# ---------- cv start ----------
# --- tuning end ---
# target size: 261
# ------ best hyper pars:  (15,) ------
# BRF starts:
# BRF ends:
# -----------
# AUPRperdrug: 0.5956193593357214
# AUROCperdrug: 0.9045525726515907
# AUPR+AUROCperdrug: 1.5001719319873121
# AUPR: 0.498037571212462
# AUROC: 0.8006636528600795
# AUPR+AUROC: 1.2987012240725415
# -----------
# run time:  836.9505243301392
